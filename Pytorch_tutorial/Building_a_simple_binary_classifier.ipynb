# %% [markdown]
# <a href="https://colab.research.google.com/github/Regina-Arthur/Coding-Practice-Projects/blob/main/Pytorch_tutorial/Building_a_simple_binary_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("cybersimar08/binary-classification-of-bank-churn-synthetic-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 11.6M/11.6M [00:00<00:00, 108MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/cybersimar08/binary-classification-of-bank-churn-synthetic-data/versions/1

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Replace the path with the output you received in Step 2
# !cp -r "/root/.cache/kagglehub/datasets/cybersimar08/binary-classification-of-bank-churn-synthetic-data" "/content/drive/MyDrive/binary-classification-of-bank-churn-synthetic-data"

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('/content/drive/MyDrive/binary-classification-of-bank-churn-synthetic-data/versions/1/Dataset.csv')

# Look at first few rows
print(df.head())

# Check structure
print(df.info())

# Check for missing values
print(df.isnull().sum())

# Class balance
print(df['Exited'].value_counts(normalize=True))
# Out:
#    Surname  CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0     2023        668.0  33.0     3.0       0.00            2.0          1
# 1     2024        627.0  33.0     1.0       0.00            2.0          1
# 2     1236        678.0  40.0    10.0       0.00            2.0          1
# 3     1362        581.0  34.0     2.0  148882.54            1.0          1
# 4      491        716.0  33.0     5.0       0.00            2.0          1
#
#    IsActiveMember  EstimatedSalary  Exited  ...  France  Germany  Spain  \
# 0               0        181449.97       0  ...       1        0      0
# 1               1         49503.50       0  ...       1        0      0
# 2               0        184866.69       0  ...       1        0      0
# 3               1         84560.88       0  ...       1        0      0
# 4               1         15068.83       0  ...       0        0      1
#
#    Female  Male  Mem__no__Products  Cred_Bal_Sal   Bal_sal  Tenure_Age  \
# ...
